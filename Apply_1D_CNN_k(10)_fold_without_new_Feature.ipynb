# %%
# Install necessary packages
# !pip install catboost dask[dataframe] xgboost lightgbm seaborn matplotlib scikit-learn imbalanced-learn statsmodels scipy tensorflow

# Step 2: Import Libraries
print("Step 2: Importing Libraries")
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler, PolynomialFeatures
from sklearn.model_selection import StratifiedKFold
from sklearn.decomposition import PCA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# Step 3: Load Dataset
print("Step 3: Loading Dataset")
df = pd.read_csv('/content/heart_statlog_cleveland_hungary_final.csv')
print("Dataset Loaded: ")
print(df.head())  # Verify the dataset

# Step 4: Handle Missing/Null Values
print("Step 4: Handling Missing/Null Values")
for column in df.columns:
    if df[column].dtype == 'object':  # Categorical
        df[column] = df[column].fillna(df[column].mode()[0])
    else:  # Numerical
        if df[column].skew() > 1:  # Outliers exist
            df[column] = df[column].fillna(df[column].median())
        else:
            df[column] = df[column].fillna(df[column].mean())
print("Null values handled.")

# Step 5: Feature Encoding
print("Step 5: Feature Encoding")
label_encoder = LabelEncoder()

# Combine Original and New Features for PCA
all_features = df.drop(columns=['target'])  # Exclude the target column
print("Feature Combination Completed.")

# Step 17: Feature Scaling
print("Step 17: Feature Scaling")
scaler = StandardScaler()
all_features_scaled = scaler.fit_transform(all_features)

# Step 28: Apply PCA on All Features and Display Component Count
print("Step 28: Applying PCA on All Features")
pca = PCA(n_components=0.95)  # Retain 95% variance
all_features_pca = pca.fit_transform(all_features_scaled)
print(f"Reduced Features Shape after PCA: {all_features_pca.shape}")

# Reshape data to fit 1D CNN input requirements
X_cnn = all_features_pca.reshape(all_features_pca.shape[0], all_features_pca.shape[1], 1)

# Display the number of retained PCA components
num_pca_components = all_features_pca.shape[1]
print(f"Number of PCA Components Retained: {num_pca_components}")

# Initialize Stratified K-Fold
n_splits = 10  # You can adjust this value
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Extract features and target
X = X_cnn  # 1D CNN input shape
y = df['target'].values

fold_accuracies = []

for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
    print(f"\nStarting Fold {fold + 1}/{n_splits}")

    # Split data into train and test for this fold
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Rebuild the model for each fold
    cnn_model = Sequential([
        Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(X_train.shape[1], 1)),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.3),
        Conv1D(filters=128, kernel_size=2, activation='relu'),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.3),
        Flatten(),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])

    # Compile the model
    initial_lr = 0.001
    optimizer = Adam(learning_rate=initial_lr)
    cnn_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    # Learning rate scheduler to reduce learning rate on plateau
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)

    # Train the model
    cnn_history = cnn_model.fit(
        X_train, y_train,
        epochs=200,  # Reduced epochs for faster execution during k-fold
        batch_size=32,
        validation_data=(X_test, y_test),
        callbacks=[lr_scheduler],
        verbose=1
    )

    # Evaluate the model
    loss, accuracy = cnn_model.evaluate(X_test, y_test, verbose=0)
    fold_accuracies.append(accuracy)
    print(f"Fold {fold + 1} Accuracy: {accuracy:.4f}")

    # Evaluate the model on the test set and get loss and accuracy
    cnn_loss, cnn_accuracy = cnn_model.evaluate(X_test, y_test)
    print(f"1D CNN Model Accuracy: {cnn_accuracy:.4f}")
    print(f"1D CNN Model Loss: {cnn_loss:.4f}")  # Print model loss

    # Generate Confusion Matrix
    y_pred_cnn = cnn_model.predict(X_test)
    y_pred_cnn = (y_pred_cnn > 0.5).astype(int)  # Convert probabilities to class labels

    # Compute confusion matrix
    cm = confusion_matrix(y_test, y_pred_cnn)

    # Calculate specificity
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp)
    print(f"Specificity: {specificity:.4f}")

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["No Disease", "Disease"], yticklabels=["No Disease", "Disease"])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

    # Print classification report
    print("Classification Report:")
    report = classification_report(y_test, y_pred_cnn, digits=4)
    print(report)

    # Plot ROC Curve
    fpr, tpr, _ = roc_curve(y_test, cnn_model.predict(X_test))
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.4f}')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.show()

    # Plot Accuracy Over Epochs
    plt.figure(figsize=(12, 6))
    plt.plot(cnn_history.history['accuracy'], label='Training Accuracy')
    plt.plot(cnn_history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('1D CNN Model Accuracy')
    plt.legend()
    plt.show()

    # Plot Loss Over Epochs
    plt.figure(figsize=(12, 6))
    plt.plot(cnn_history.history['loss'], label='Training Loss')
    plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('1D CNN Model Loss')
    plt.legend()
    plt.show()
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.3)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.12.4)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.14.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.10/dist-packages (2024.10.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (8.5.0)
# Collecting dask-expr<1.2,>=1.1 (from dask[dataframe])
#   Downloading dask_expr-1.1.21-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# INFO: pip is looking at multiple versions of dask-expr to determine which version is compatible with other requirements. This could take a while.
#   Downloading dask_expr-1.1.20-py3-none-any.whl.metadata (2.6 kB)
#   Downloading dask_expr-1.1.19-py3-none-any.whl.metadata (2.6 kB)
#   Downloading dask_expr-1.1.18-py3-none-any.whl.metadata (2.6 kB)
#   Downloading dask_expr-1.1.16-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.10/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]) (17.0.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 9.5 MB/s eta 0:00:00
# Downloading dask_expr-1.1.16-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 17.0 MB/s eta 0:00:00
# Installing collected packages: dask-expr, catboost
# Successfully installed catboost-1.2.7 dask-expr-1.1.16
# Step 2: Importing Libraries
# Step 3: Loading Dataset
# Dataset Loaded:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0
# Step 4: Handling Missing/Null Values
# Null values handled.
# Step 5: Feature Encoding
# Feature Combination Completed.
# Step 17: Feature Scaling
# Step 28: Applying PCA on All Features
# Reduced Features Shape after PCA: (1190, 10)
# Number of PCA Components Retained: 10
#
# Starting Fold 1/10
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.6037 - loss: 0.8077 - val_accuracy: 0.7479 - val_loss: 0.6465 - learning_rate: 0.0010
# Epoch 2/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7332 - loss: 0.5713 - val_accuracy: 0.7227 - val_loss: 0.6178 - learning_rate: 0.0010
# Epoch 3/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7401 - loss: 0.5542 - val_accuracy: 0.5966 - val_loss: 0.6162 - learning_rate: 0.0010
# Epoch 4/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7740 - loss: 0.5190 - val_accuracy: 0.5882 - val_loss: 0.6373 - learning_rate: 0.0010
# Epoch 5/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7646 - loss: 0.5618 - val_accuracy: 0.6134 - val_loss: 0.5988 - learning_rate: 0.0010
# Epoch 6/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7685 - loss: 0.4631 - val_accuracy: 0.6639 - val_loss: 0.5786 - learning_rate: 0.0010
# Epoch 7/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7734 - loss: 0.5001 - val_accuracy: 0.6303 - val_loss: 0.5998 - learning_rate: 0.0010
# Epoch 8/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8037 - loss: 0.4800 - val_accuracy: 0.6807 - val_loss: 0.5671 - learning_rate: 0.0010
# Epoch 9/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8094 - loss: 0.4220 - val_accuracy: 0.7059 - val_loss: 0.5418 - learning_rate: 0.0010
# Epoch 10/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8048 - loss: 0.4395 - val_accuracy: 0.7563 - val_loss: 0.4961 - learning_rate: 0.0010
# Epoch 11/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7966 - loss: 0.4522 - val_accuracy: 0.7731 - val_loss: 0.5074 - learning_rate: 0.0010
# Epoch 12/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8145 - loss: 0.4275 - val_accuracy: 0.7731 - val_loss: 0.4707 - learning_rate: 0.0010
# Epoch 13/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8197 - loss: 0.4216 - val_accuracy: 0.8067 - val_loss: 0.4499 - learning_rate: 0.0010
# Epoch 14/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7839 - loss: 0.4563 - val_accuracy: 0.7815 - val_loss: 0.4818 - learning_rate: 0.0010
# Epoch 15/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8087 - loss: 0.4124 - val_accuracy: 0.7731 - val_loss: 0.4669 - learning_rate: 0.0010
# Epoch 16/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8023 - loss: 0.4212 - val_accuracy: 0.7815 - val_loss: 0.4614 - learning_rate: 0.0010
# Epoch 17/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7819 - loss: 0.4428 - val_accuracy: 0.7983 - val_loss: 0.4649 - learning_rate: 0.0010
# Epoch 18/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8159 - loss: 0.4162 - val_accuracy: 0.8235 - val_loss: 0.4389 - learning_rate: 0.0010
# Epoch 19/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8027 - loss: 0.3981 - val_accuracy: 0.7983 - val_loss: 0.4611 - learning_rate: 0.0010
# Epoch 20/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8233 - loss: 0.3826 - val_accuracy: 0.7983 - val_loss: 0.4488 - learning_rate: 0.0010
# Epoch 21/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8125 - loss: 0.3930 - val_accuracy: 0.8067 - val_loss: 0.4469 - learning_rate: 0.0010
# Epoch 22/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8288 - loss: 0.3930 - val_accuracy: 0.7983 - val_loss: 0.4547 - learning_rate: 0.0010
# Epoch 23/200
# 28/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8294 - loss: 0.3704
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8279 - loss: 0.3757 - val_accuracy: 0.7983 - val_loss: 0.4421 - learning_rate: 0.0010
# Epoch 24/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8532 - loss: 0.3712 - val_accuracy: 0.7899 - val_loss: 0.4427 - learning_rate: 5.0000e-04
# Epoch 25/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8393 - loss: 0.3617 - val_accuracy: 0.7899 - val_loss: 0.4460 - learning_rate: 5.0000e-04
# Epoch 26/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8347 - loss: 0.3449 - val_accuracy: 0.7899 - val_loss: 0.4470 - learning_rate: 5.0000e-04
# Epoch 27/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8211 - loss: 0.4043 - val_accuracy: 0.7983 - val_loss: 0.4406 - learning_rate: 5.0000e-04
# Epoch 28/200
# 25/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8603 - loss: 0.3482
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8544 - loss: 0.3564 - val_accuracy: 0.7983 - val_loss: 0.4510 - learning_rate: 5.0000e-04
# Epoch 29/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8244 - loss: 0.3844 - val_accuracy: 0.7983 - val_loss: 0.4481 - learning_rate: 2.5000e-04
# Epoch 30/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8462 - loss: 0.3636 - val_accuracy: 0.7983 - val_loss: 0.4500 - learning_rate: 2.5000e-04
# Epoch 31/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8305 - loss: 0.3777 - val_accuracy: 0.7983 - val_loss: 0.4479 - learning_rate: 2.5000e-04
# Epoch 32/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8445 - loss: 0.3811 - val_accuracy: 0.7983 - val_loss: 0.4433 - learning_rate: 2.5000e-04
# Epoch 33/200
# 27/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8314 - loss: 0.3835
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8324 - loss: 0.3833 - val_accuracy: 0.7983 - val_loss: 0.4489 - learning_rate: 2.5000e-04
# Epoch 34/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8308 - loss: 0.3976 - val_accuracy: 0.7899 - val_loss: 0.4484 - learning_rate: 1.2500e-04
# Epoch 35/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8277 - loss: 0.3902 - val_accuracy: 0.8067 - val_loss: 0.4432 - learning_rate: 1.2500e-04
# Epoch 36/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8368 - loss: 0.3447 - val_accuracy: 0.8067 - val_loss: 0.4432 - learning_rate: 1.2500e-04
# Epoch 37/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8371 - loss: 0.3407 - val_accuracy: 0.8067 - val_loss: 0.4420 - learning_rate: 1.2500e-04
# Epoch 38/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8329 - loss: 0.3874
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8334 - loss: 0.3865 - val_accuracy: 0.8067 - val_loss: 0.4415 - learning_rate: 1.2500e-04
# Epoch 39/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8435 - loss: 0.3455 - val_accuracy: 0.7983 - val_loss: 0.4435 - learning_rate: 6.2500e-05
# Epoch 40/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8420 - loss: 0.3581 - val_accuracy: 0.7983 - val_loss: 0.4430 - learning_rate: 6.2500e-05
# Epoch 41/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8325 - loss: 0.3906 - val_accuracy: 0.7899 - val_loss: 0.4422 - learning_rate: 6.2500e-05
# Epoch 42/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8395 - loss: 0.3726 - val_accuracy: 0.7899 - val_loss: 0.4426 - learning_rate: 6.2500e-05
# Epoch 43/200
# 23/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8451 - loss: 0.3687
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8435 - loss: 0.3679 - val_accuracy: 0.7899 - val_loss: 0.4440 - learning_rate: 6.2500e-05
# Epoch 44/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8303 - loss: 0.3726 - val_accuracy: 0.7899 - val_loss: 0.4453 - learning_rate: 3.1250e-05
# Epoch 45/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8573 - loss: 0.3345 - val_accuracy: 0.7899 - val_loss: 0.4446 - learning_rate: 3.1250e-05
# Epoch 46/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8284 - loss: 0.3701 - val_accuracy: 0.7899 - val_loss: 0.4445 - learning_rate: 3.1250e-05
# Epoch 47/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8341 - loss: 0.3992 - val_accuracy: 0.7899 - val_loss: 0.4442 - learning_rate: 3.1250e-05
# Epoch 48/200
# 33/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8364 - loss: 0.3641
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8361 - loss: 0.3649 - val_accuracy: 0.7983 - val_loss: 0.4451 - learning_rate: 3.1250e-05
# Epoch 49/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8273 - loss: 0.3801 - val_accuracy: 0.7899 - val_loss: 0.4450 - learning_rate: 1.5625e-05
# Epoch 50/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8457 - loss: 0.3539 - val_accuracy: 0.7899 - val_loss: 0.4446 - learning_rate: 1.5625e-05
# Epoch 51/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8338 - loss: 0.3798 - val_accuracy: 0.7899 - val_loss: 0.4446 - learning_rate: 1.5625e-05
# Epoch 52/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8421 - loss: 0.3688 - val_accuracy: 0.7899 - val_loss: 0.4441 - learning_rate: 1.5625e-05
# Epoch 53/200
# 31/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8335 - loss: 0.3877
# Epoch 53: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8328 - loss: 0.3862 - val_accuracy: 0.7983 - val_loss: 0.4441 - learning_rate: 1.5625e-05
# Epoch 54/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8324 - loss: 0.3722 - val_accuracy: 0.7899 - val_loss: 0.4435 - learning_rate: 7.8125e-06
# Epoch 55/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8400 - loss: 0.3680 - val_accuracy: 0.7899 - val_loss: 0.4438 - learning_rate: 7.8125e-06
# Epoch 56/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8143 - loss: 0.4037 - val_accuracy: 0.7899 - val_loss: 0.4435 - learning_rate: 7.8125e-06
# Epoch 57/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8170 - loss: 0.3891 - val_accuracy: 0.7899 - val_loss: 0.4433 - learning_rate: 7.8125e-06
# Epoch 58/200
# 27/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8107 - loss: 0.4255
# Epoch 58: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8157 - loss: 0.4141 - val_accuracy: 0.7983 - val_loss: 0.4431 - learning_rate: 7.8125e-06
# Epoch 59/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8124 - loss: 0.4114 - val_accuracy: 0.7983 - val_loss: 0.4427 - learning_rate: 3.9063e-06
# Epoch 60/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8439 - loss: 0.3648 - val_accuracy: 0.7899 - val_loss: 0.4427 - learning_rate: 3.9063e-06
# Epoch 61/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8373 - loss: 0.3622 - val_accuracy: 0.7899 - val_loss: 0.4428 - learning_rate: 3.9063e-06
# Epoch 62/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8263 - loss: 0.3873 - val_accuracy: 0.7983 - val_loss: 0.4428 - learning_rate: 3.9063e-06
# Epoch 63/200
# 24/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8305 - loss: 0.3822
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8278 - loss: 0.3847 - val_accuracy: 0.7899 - val_loss: 0.4427 - learning_rate: 3.9063e-06
# Epoch 64/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8451 - loss: 0.3564 - val_accuracy: 0.7899 - val_loss: 0.4429 - learning_rate: 1.9531e-06
# Epoch 65/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8574 - loss: 0.3390 - val_accuracy: 0.7899 - val_loss: 0.4433 - learning_rate: 1.9531e-06
# Epoch 66/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8460 - loss: 0.3472 - val_accuracy: 0.7899 - val_loss: 0.4435 - learning_rate: 1.9531e-06
# Epoch 67/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8530 - loss: 0.3649 - val_accuracy: 0.7899 - val_loss: 0.4433 - learning_rate: 1.9531e-06
# Epoch 68/200
# 30/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8242 - loss: 0.3621
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1e-06.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8241 - loss: 0.3627 - val_accuracy: 0.7899 - val_loss: 0.4431 - learning_rate: 1.9531e-06
# Epoch 69/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8272 - loss: 0.3644 - val_accuracy: 0.7899 - val_loss: 0.4432 - learning_rate: 1.0000e-06
# Epoch 70/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8392 - loss: 0.3551 - val_accuracy: 0.7899 - val_loss: 0.4441 - learning_rate: 1.0000e-06
# Epoch 71/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7980 - loss: 0.4052 - val_accuracy: 0.7899 - val_loss: 0.4435 - learning_rate: 1.0000e-06
# Epoch 72/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8317 - loss: 0.3664 - val_accuracy: 0.7899 - val_loss: 0.4436 - learning_rate: 1.0000e-06
# Epoch 73/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8254 - loss: 0.3696 - val_accuracy: 0.7899 - val_loss: 0.4433 - learning_rate: 1.0000e-06
# Epoch 74/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8385 - loss: 0.3680 - val_accuracy: 0.7899 - val_loss: 0.4434 - learning_rate: 1.0000e-06
# Epoch 75/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8433 - loss: 0.3765 - val_accuracy: 0.7899 - val_loss: 0.4426 - learning_rate: 1.0000e-06
# Epoch 76/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8344 - loss: 0.3575 - val_accuracy: 0.7899 - val_loss: 0.4427 - learning_rate: 1.0000e-06
# Epoch 77/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8505 - loss: 0.3645 - val_accuracy: 0.7899 - val_loss: 0.4426 - learning_rate: 1.0000e-06
# Epoch 78/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8526 - loss: 0.3565 - val_accuracy: 0.7899 - val_loss: 0.4422 - learning_rate: 1.0000e-06
# Epoch 79/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8457 - loss: 0.3642 - val_accuracy: 0.7899 - val_loss: 0.4417 - learning_rate: 1.0000e-06
# Epoch 80/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8330 - loss: 0.3502 - val_accuracy: 0.7983 - val_loss: 0.4416 - learning_rate: 1.0000e-06
# Epoch 81/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8464 - loss: 0.3689 - val_accuracy: 0.7899 - val_loss: 0.4419 - learning_rate: 1.0000e-06
# Epoch 82/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8245 - loss: 0.4067 - val_accuracy: 0.7899 - val_loss: 0.4423 - learning_rate: 1.0000e-06
# Epoch 83/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8508 - loss: 0.3537 - val_accuracy: 0.7899 - val_loss: 0.4425 - learning_rate: 1.0000e-06
# Epoch 84/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8383 - loss: 0.3492 - val_accuracy: 0.7899 - val_loss: 0.4428 - learning_rate: 1.0000e-06
# Epoch 85/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8396 - loss: 0.3553 - val_accuracy: 0.7899 - val_loss: 0.4429 - learning_rate: 1.0000e-06
# Epoch 86/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8427 - loss: 0.3422 - val_accuracy: 0.7899 - val_loss: 0.4429 - learning_rate: 1.0000e-06
# Epoch 87/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8630 - loss: 0.3213 - val_accuracy: 0.7899 - val_loss: 0.4421 - learning_rate: 1.0000e-06
# Epoch 88/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8481 - loss: 0.3510 - val_accuracy: 0.7899 - val_loss: 0.4420 - learning_rate: 1.0000e-06
# Epoch 89/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8216 - loss: 0.3778 - val_accuracy: 0.7899 - val_loss: 0.4422 - learning_rate: 1.0000e-06
# Epoch 90/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8378 - loss: 0.3564 - val_accuracy: 0.7899 - val_loss: 0.4425 - learning_rate: 1.0000e-06
# Epoch 91/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8299 - loss: 0.3929 - val_accuracy: 0.7899 - val_loss: 0.4426 - learning_rate: 1.0000e-06
# Epoch 92/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8594 - loss: 0.3644 - val_accuracy: 0.7899 - val_loss: 0.4421 - learning_rate: 1.0000e-06
# Epoch 93/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8571 - loss: 0.3470 - val_accuracy: 0.7899 - val_loss: 0.4425 - learning_rate: 1.0000e-06
# Epoch 94/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8439 - loss: 0.3589 - val_accuracy: 0.7899 - val_loss: 0.4428 - learning_rate: 1.0000e-06
# Epoch 95/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8180 - loss: 0.3937 - val_accuracy: 0.7899 - val_loss: 0.4432 - learning_rate: 1.0000e-06
# Epoch 96/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8231 - loss: 0.3562 - val_accuracy: 0.7899 - val_loss: 0.4430 - learning_rate: 1.0000e-06
# Epoch 97/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8363 - loss: 0.3622 - val_accuracy: 0.7899 - val_loss: 0.4426 - learning_rate: 1.0000e-06
# Epoch 98/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8486 - loss: 0.3736 - val_accuracy: 0.7899 - val_loss: 0.4426 - learning_rate: 1.0000e-06
# Epoch 99/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8476 - loss: 0.3443 - val_accuracy: 0.7899 - val_loss: 0.4428 - learning_rate: 1.0000e-06
# Epoch 100/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8364 - loss: 0.3453 - val_accuracy: 0.7899 - val_loss: 0.4434 - learning_rate: 1.0000e-06
# Epoch 101/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8253 - loss: 0.3584 - val_accuracy: 0.7899 - val_loss: 0.4431 - learning_rate: 1.0000e-06
# Epoch 102/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8457 - loss: 0.3528 - val_accuracy: 0.7899 - val_loss: 0.4429 - learning_rate: 1.0000e-06
# Epoch 103/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7948 - loss: 0.4005 - val_accuracy: 0.7899 - val_loss: 0.4432 - learning_rate: 1.0000e-06
# Epoch 104/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8430 - loss: 0.3670 - val_accuracy: 0.7899 - val_loss: 0.4437 - learning_rate: 1.0000e-06
# Epoch 105/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8374 - loss: 0.3632 - val_accuracy: 0.7899 - val_loss: 0.4435 - learning_rate: 1.0000e-06
# Epoch 106/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8210 - loss: 0.3616 - val_accuracy: 0.7899 - val_loss: 0.4434 - learning_rate: 1.0000e-06
# Epoch 107/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8363 - loss: 0.3755 - val_accuracy: 0.7899 - val_loss: 0.4433 - learning_rate: 1.0000e-06
# Epoch 108/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8375 - loss: 0.3685 - val_accuracy: 0.7899 - val_loss: 0.4437 - learning_rate: 1.0000e-06
# Epoch 109/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
# Epoch 146/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8107 - loss: 0.4415 - val_accuracy: 0.7899 - val_loss: 0.4409 - learning_rate: 1.0000e-06
# Epoch 147/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8402 - loss: 0.3560 - val_accuracy: 0.7899 - val_loss: 0.4412 - learning_rate: 1.0000e-06
# Epoch 148/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8303 - loss: 0.3723 - val_accuracy: 0.7899 - val_loss: 0.4419 - learning_rate: 1.0000e-06
# Epoch 149/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8229 - loss: 0.3795 - val_accuracy: 0.7899 - val_loss: 0.4425 - learning_rate: 1.0000e-06
# Epoch 150/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8350 - loss: 0.3776 - val_accuracy: 0.7899 - val_loss: 0.4423 - learning_rate: 1.0000e-06
# Epoch 151/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8308 - loss: 0.3588 - val_accuracy: 0.7899 - val_loss: 0.4419 - learning_rate: 1.0000e-06
# Epoch 152/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8047 - loss: 0.4026 - val_accuracy: 0.7899 - val_loss: 0.4418 - learning_rate: 1.0000e-06
# Epoch 153/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8302 - loss: 0.3727 - val_accuracy: 0.7899 - val_loss: 0.4418 - learning_rate: 1.0000e-06
# Epoch 154/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8421 - loss: 0.3769 - val_accuracy: 0.7899 - val_loss: 0.4421 - learning_rate: 1.0000e-06
# Epoch 155/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8536 - loss: 0.3639 - val_accuracy: 0.7899 - val_loss: 0.4422 - learning_rate: 1.0000e-06
# Epoch 156/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8573 - loss: 0.3594 - val_accuracy: 0.7899 - val_loss: 0.4422 - learning_rate: 1.0000e-06
# Epoch 157/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8424 - loss: 0.3650 - val_accuracy: 0.7899 - val_loss: 0.4429 - learning_rate: 1.0000e-06
# Epoch 158/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8169 - loss: 0.4201 - val_accuracy: 0.7899 - val_loss: 0.4422 - learning_rate: 1.0000e-06
# Epoch 159/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8498 - loss: 0.3557 - val_accuracy: 0.7899 - val_loss: 0.4423 - learning_rate: 1.0000e-06
# Epoch 160/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8702 - loss: 0.3474 - val_accuracy: 0.7899 - val_loss: 0.4422 - learning_rate: 1.0000e-06
# Epoch 161/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8191 - loss: 0.3751 - val_accuracy: 0.7899 - val_loss: 0.4413 - learning_rate: 1.0000e-06
# Epoch 162/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8403 - loss: 0.3795 - val_accuracy: 0.7899 - val_loss: 0.4405 - learning_rate: 1.0000e-06
# Epoch 163/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8568 - loss: 0.3572 - val_accuracy: 0.7899 - val_loss: 0.4399 - learning_rate: 1.0000e-06
# Epoch 164/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8189 - loss: 0.3923 - val_accuracy: 0.7899 - val_loss: 0.4406 - learning_rate: 1.0000e-06
# Epoch 165/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8396 - loss: 0.3639 - val_accuracy: 0.7899 - val_loss: 0.4422 - learning_rate: 1.0000e-06
# Epoch 166/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8210 - loss: 0.3784 - val_accuracy: 0.7899 - val_loss: 0.4418 - learning_rate: 1.0000e-06
# Epoch 167/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8321 - loss: 0.3755 - val_accuracy: 0.7899 - val_loss: 0.4412 - learning_rate: 1.0000e-06
# Epoch 168/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8503 - loss: 0.3508 - val_accuracy: 0.7899 - val_loss: 0.4410 - learning_rate: 1.0000e-06
# Epoch 169/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8583 - loss: 0.3357 - val_accuracy: 0.7899 - val_loss: 0.4416 - learning_rate: 1.0000e-06
# Epoch 170/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8402 - loss: 0.3598 - val_accuracy: 0.7899 - val_loss: 0.4410 - learning_rate: 1.0000e-06
# Epoch 171/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8124 - loss: 0.3800 - val_accuracy: 0.7899 - val_loss: 0.4412 - learning_rate: 1.0000e-06
# Epoch 172/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8444 - loss: 0.3271 - val_accuracy: 0.7899 - val_loss: 0.4414 - learning_rate: 1.0000e-06
# Epoch 173/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8362 - loss: 0.3525 - val_accuracy: 0.7899 - val_loss: 0.4419 - learning_rate: 1.0000e-06
# Epoch 174/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8611 - loss: 0.3397 - val_accuracy: 0.7899 - val_loss: 0.4421 - learning_rate: 1.0000e-06
# Epoch 175/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8010 - loss: 0.3958 - val_accuracy: 0.7899 - val_loss: 0.4420 - learning_rate: 1.0000e-06
# Epoch 176/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8404 - loss: 0.3668 - val_accuracy: 0.7899 - val_loss: 0.4421 - learning_rate: 1.0000e-06
# Epoch 177/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8270 - loss: 0.3692 - val_accuracy: 0.7899 - val_loss: 0.4423 - learning_rate: 1.0000e-06
# Epoch 178/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8693 - loss: 0.3237 - val_accuracy: 0.7899 - val_loss: 0.4429 - learning_rate: 1.0000e-06
# Epoch 179/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8444 - loss: 0.3787 - val_accuracy: 0.7899 - val_loss: 0.4432 - learning_rate: 1.0000e-06
# Epoch 180/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8733 - loss: 0.3278 - val_accuracy: 0.7899 - val_loss: 0.4422 - learning_rate: 1.0000e-06
# Epoch 181/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8354 - loss: 0.3850 - val_accuracy: 0.7899 - val_loss: 0.4424 - learning_rate: 1.0000e-06
# Epoch 182/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8291 - loss: 0.3697 - val_accuracy: 0.7899 - val_loss: 0.4426 - learning_rate: 1.0000e-06
# Epoch 183/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8422 - loss: 0.3896 - val_accuracy: 0.7899 - val_loss: 0.4417 - learning_rate: 1.0000e-06
# Epoch 184/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8330 - loss: 0.3572 - val_accuracy: 0.7899 - val_loss: 0.4412 - learning_rate: 1.0000e-06
# Epoch 185/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8554 - loss: 0.3418 - val_accuracy: 0.7899 - val_loss: 0.4413 - learning_rate: 1.0000e-06
# Epoch 186/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8440 - loss: 0.3552 - val_accuracy: 0.7899 - val_loss: 0.4411 - learning_rate: 1.0000e-06
# Epoch 187/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8340 - loss: 0.3781 - val_accuracy: 0.7899 - val_loss: 0.4415 - learning_rate: 1.0000e-06
# Epoch 188/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8252 - loss: 0.3815 - val_accuracy: 0.7899 - val_loss: 0.4409 - learning_rate: 1.0000e-06
# Epoch 189/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8391 - loss: 0.3482 - val_accuracy: 0.7899 - val_loss: 0.4408 - learning_rate: 1.0000e-06
# Epoch 190/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8256 - loss: 0.3722 - val_accuracy: 0.7899 - val_loss: 0.4411 - learning_rate: 1.0000e-06
# Epoch 191/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8534 - loss: 0.3553 - val_accuracy: 0.7899 - val_loss: 0.4404 - learning_rate: 1.0000e-06
# Epoch 192/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8496 - loss: 0.3642 - val_accuracy: 0.7899 - val_loss: 0.4405 - learning_rate: 1.0000e-06
# Epoch 193/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8386 - loss: 0.3805 - val_accuracy: 0.7899 - val_loss: 0.4408 - learning_rate: 1.0000e-06
# Epoch 194/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8237 - loss: 0.3714 - val_accuracy: 0.7899 - val_loss: 0.4413 - learning_rate: 1.0000e-06
# Epoch 195/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8648 - loss: 0.3451 - val_accuracy: 0.7899 - val_loss: 0.4415 - learning_rate: 1.0000e-06
# Epoch 196/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8602 - loss: 0.3584 - val_accuracy: 0.7899 - val_loss: 0.4418 - learning_rate: 1.0000e-06
# Epoch 197/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8621 - loss: 0.3454 - val_accuracy: 0.7899 - val_loss: 0.4412 - learning_rate: 1.0000e-06
# Epoch 198/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8634 - loss: 0.3446 - val_accuracy: 0.7899 - val_loss: 0.4409 - learning_rate: 1.0000e-06
# Epoch 199/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8514 - loss: 0.3478 - val_accuracy: 0.7899 - val_loss: 0.4409 - learning_rate: 1.0000e-06
# Epoch 200/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8189 - loss: 0.4005 - val_accuracy: 0.7899 - val_loss: 0.4411 - learning_rate: 1.0000e-06
# Fold 1 Accuracy: 0.7899
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7930 - loss: 0.4189
# 1D CNN Model Accuracy: 0.7899
# 1D CNN Model Loss: 0.4411
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Specificity: 0.7719
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7857    0.7719    0.7788        57
#            1     0.7937    0.8065    0.8000        62
#
#     accuracy                         0.7899       119
#    macro avg     0.7897    0.7892    0.7894       119
# weighted avg     0.7898    0.7899    0.7898       119
#
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Starting Fold 2/10
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.5969 - loss: 0.8787 - val_accuracy: 0.7815 - val_loss: 0.6367 - learning_rate: 0.0010
# Epoch 2/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7405 - loss: 0.5926 - val_accuracy: 0.8067 - val_loss: 0.6028 - learning_rate: 0.0010
# Epoch 3/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7490 - loss: 0.6163 - val_accuracy: 0.7983 - val_loss: 0.5706 - learning_rate: 0.0010
# Epoch 4/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7536 - loss: 0.6168 - val_accuracy: 0.7815 - val_loss: 0.5466 - learning_rate: 0.0010
# Epoch 5/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7763 - loss: 0.5122 - val_accuracy: 0.7731 - val_loss: 0.5328 - learning_rate: 0.0010
# Epoch 6/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7567 - loss: 0.5788 - val_accuracy: 0.7647 - val_loss: 0.5087 - learning_rate: 0.0010
# Epoch 7/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7786 - loss: 0.4754 - val_accuracy: 0.7899 - val_loss: 0.4764 - learning_rate: 0.0010
# Epoch 8/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7639 - loss: 0.4864 - val_accuracy: 0.7983 - val_loss: 0.4450 - learning_rate: 0.0010
# Epoch 9/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7744 - loss: 0.4841 - val_accuracy: 0.7983 - val_loss: 0.4438 - learning_rate: 0.0010
# Epoch 10/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.